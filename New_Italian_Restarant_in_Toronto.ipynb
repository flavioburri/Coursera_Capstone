# %% [markdown]
# <H1> Battle of the Neighbourhoods
#
# <H2> New Italian Restaurnat in Munich

# %% [markdown]
# Author: Flavio Burri

# %% [markdown]
# ## Table of contents
# * [Introduction and description of business problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#conclusion)

# %% [markdown]
# ### Introduction and description of business problem <a name="introduction"></a>

# %% [markdown]
# To open a new restaurant is a challenge due to many different reasons. One of the hardest task is to decide WHERE to open the restaurant (e.g. an Italian Restaurant) within the city that you decided. The present exercise aim to help the hypothetical owner of the new Italian restaurant to locate his activity within the city of Toronto (in Canada). Leveraging Data Science can help to simplify this task and supporting the owner to find out the best place of the city where opening the restaurant.
# The work will be of understanding where are located other Italian restaurants in Toronto  keeping in mind the idea that normally the people prefer going out for a meal in a place where there are also other kind of meeting venues like coffees and bars. We will also investigate if there is a correlation between some specific venues and restaurants in a particular neighborhood in order to evaluate if some meeting places can be found more frequently near the restaurants. This will help us to identify a location for our restaurant where there are less competitors.

# %% [markdown]
# ### Data <a name="data"></a>

# %% [markdown]
# The data we will use are:
# -	List of the neighborhoods of Toronto coming from scrapping a Wikipedia web page. (See the notebook)
# -	List of Latitudes and Longitudes of all neighborhoods coming from a file used in a previous exercise of this course.
# -	List of Italian restaurants and other venues of the city found leveraging Foursquare API.
#
# All those data will helps to do our job which will be starting by understanding where are located all the Italian restaurants in Toronto.
# After we will investigate if there is a correlation between others social venues and restaurants in these neighborhoods. The idea is to evaluate if some venues might be found more frequently near restaurants. If this correlation is applicable e.g. with bars, this will help to identify possible locations for the new restaurant. Those suitable locations will be where there is a high density of the meeting venues (e.g. bars) and just few restaurants (and no Italian restaurants) nearby.

# %% [markdown]
# ### Methodology <a name="methodology"></a>

# %% [markdown]
# First we collect the data necessary to set up the model. We have already created a database of Toronto locations in an exercise before that will be uploaded into this notebook.
# We will use these data along with geospatial and Foursquare data to define the area of interest by looking at where the majority of Italian Restaurants are located in Toronto. After that, we will use the data to understand which are the most frequent venues near the other Italian Restaurants, and use these data to create a simple graphic from which we will be able to define the best location for the new Restaurant.

# %% [markdown]
# First, let's install some useful libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %%
#!conda update -n base -c defaults conda --yes

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# ##### Scraping a table from Wikipedia and clean the table

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
df = pd.read_html(url)
len(df)
# Out:
# 3

# %%
#Reading the table which is in the first place and set the header
df_toronto = df[0]
new_header = df_toronto.iloc[0] #grab the first row for the header
df_toronto = df_toronto[1:] #take the data less the header row
df_toronto.columns = new_header #set the header row as the df_toronto header
df_toronto.head()
# Out:
# 0 Postal Code           Borough              Neighbourhood
# 1         M1A      Not assigned               Not assigned
# 2         M2A      Not assigned               Not assigned
# 3         M3A        North York                  Parkwoods
# 4         M4A        North York           Victoria Village
# 5         M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
df_toronto.shape
# Out:
# (180, 3)

# %% [markdown]
# ##### Creating the dataframe containing the geographical coordinates of the neighborhoods

# %% [markdown]
# We import csv data of Toronto from file (reference http://cocl.us/Geospatial_data)

# %%
#importing the csv file with coordinates
geo = pd.read_csv('http://cocl.us/Geospatial_data')
geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
geo.shape
# Out:
# (103, 3)

# %% [markdown]
# We can merge the two dataframes and create a new one

# %%
# merging table with neighbourhoods and the one above with coordinates
df_toronto = pd.merge(df_toronto, geo, on='Postal Code')
df_toronto.head()
# Out:
#   Postal Code           Borough                                Neighbourhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# ##### Exploring and clustering the neighborhoods in Toronto and visualise them on the maps as clusters

# %%
#!wget -q -O 'toronto_data.json' http://adamw523.com/toronto-geojson/
#print('Data downloaded!')

# %%
# Define the Foursquare credentials and version---------------
# My personal credentiala after use will be removed for privacy reason

CLIENT_ID = 'PUR3VSJFUQSEHZ3MKTY5OLTU5OJG4NMFKP2WBGIGFJXG10RS' # your Foursquare ID
CLIENT_SECRET = 'THK4KZ2T2BQVWMIPVJFWDMOGYR4SO5XZ5UD5FEPZP0P35LDP' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 10000
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: PUR3VSJFUQSEHZ3MKTY5OLTU5OJG4NMFKP2WBGIGFJXG10RS
# CLIENT_SECRET:THK4KZ2T2BQVWMIPVJFWDMOGYR4SO5XZ5UD5FEPZP0P35LDP

# %%
# Using geopy library to get geopy long. and latit. of Toronto-------------

address_TO = 'Toronto, ON'
geolocator = Nominatim(user_agent="toronto_agent")
location = geolocator.geocode(address_TO)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
#Visualize Toronto maps with Folium------------------------------

toronto_map = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_toronto['Latitude'], df_toronto['Longitude'], df_toronto['Borough'], df_toronto['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(toronto_map)  
    
toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### We create a function to get names and information on the venues for all the neighbourhoods in Toronto

# %%
# Explore neighbourhoods in Toronto-----------------------
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Postal Code', 'Neighbourhood Latitude', 
                             'Neighbourhood Longitude', 
                             'Venue', 
                             'Venue Latitude', 
                             'Venue Longitude', 
                             'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=df_toronto['Postal Code'],
                                   latitudes=df_toronto['Latitude'],
                                   longitudes=df_toronto['Longitude']
                                  )
toronto_venues.head()
# Out:
#   Postal Code  Neighbourhood Latitude  Neighbourhood Longitude  \
# 0         M3A               43.753259               -79.329656
# 1         M3A               43.753259               -79.329656
# 2         M4A               43.725882               -79.315572
# 3         M4A               43.725882               -79.315572
# 4         M4A               43.725882               -79.315572
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0         Brookbanks Park       43.751976       -79.332140
# 1           Variety Store       43.751974       -79.333114
# 2  Victoria Village Arena       43.723481       -79.315635
# 3             Tim Hortons       43.725517       -79.313103
# 4               Portugril       43.725819       -79.312785
#
#           Venue Category
# 0                   Park
# 1      Food & Drink Shop
# 2           Hockey Arena
# 3            Coffee Shop
# 4  Portuguese Restaurant

# %% [markdown]
# ##### Now we can create a dataframe of venues with category "Italian Restaurant"

# %%
toronto_venues_it_rest = toronto_venues[toronto_venues['Venue Category'] == 'Italian Restaurant']
toronto_venues_it_rest.head()
# Out:
#     Postal Code  Neighbourhood Latitude  Neighbourhood Longitude  \
# 66          M7A               43.662301               -79.389494
# 163         M5B               43.657162               -79.378937
# 181         M5B               43.657162               -79.378937
# 222         M3C               43.725900               -79.340923
# 254         M5C               43.651494               -79.375418
#
#                                 Venue  Venue Latitude  Venue Longitude  \
# 66                           Mercatto       43.660391       -79.387664
# 163  Scaddabush Italian Kitchen & Bar       43.658920       -79.382891
# 181                Trattoria Mercatto       43.654453       -79.380974
# 222                Sorento Restaurant       43.726575       -79.341989
# 254                           Terroni       43.650927       -79.375602
#
#          Venue Category
# 66   Italian Restaurant
# 163  Italian Restaurant
# 181  Italian Restaurant
# 222  Italian Restaurant
# 254  Italian Restaurant

# %% [markdown]
# Now we need to understand which is the most common Venue around an Italian Restaurant.
# This will help us in defining in a more precise way the area in which an Italian Restaurant is more likely to have success and customers.
# ##### Creating a dataframe with the distances between Italian Restaurants and the other Venues.

# %%
from math import radians, cos, sin, asin, sqrt

#define a function to evaluate distance between venues
#ref. https://en.wikipedia.org/wiki/Haversine_formula

def haversine(lon1, lat1, lon2, lat2):
  # convert decimal degrees to radians 
  lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
 
  # haversine formula 
  distance_lon = lon2 - lon1 
  distance_lat = lat2 - lat1
  a = sin(distance_lat/2)**2 + cos(lat1) * cos(lat2) * sin(distance_lon/2)**2
  earth_r = 6371 # Radius of earth in kilometers. Use 3956 for miles
    
  return 2 * asin(sqrt(a)) * earth_r #result in km

restaurant_venues = pd.DataFrame(columns = ['Restaurant','Venue type', 'Restaurant longitude', 'Restaurant latitude', 'Venue longitude','Venue latitude', 'Distance'])

for rest, lng, lat in zip(toronto_venues_it_rest['Venue Category'], toronto_venues_it_rest['Venue Longitude'], toronto_venues_it_rest['Venue Latitude']):
    for venue, lng2, lat2 in zip(toronto_venues['Venue Category'], toronto_venues['Venue Longitude'], toronto_venues['Venue Latitude']):
        distance = haversine(lng, lat, lng2, lat2)
        restaurant_venues = restaurant_venues.append({'Restaurant': rest, 
                                                      'Venue type': venue, 
                                                      'Restaurant longitude': lng,
                                                      'Restaurant latitude': lat,
                                                      'Venue longitude': lng2,
                                                      'Venue latitude': lat2,
                                                      'Distance': distance
                                                     }, ignore_index=True)

print('----------------Database created!----------------')
# Out:
# ----------------Database created!----------------

# %%
restaurant_venues.shape
# Out:
# (87781, 7)

# %% [markdown]
# We then filter the database by removing informations not useful with the following criteria
#
# 1. Rows where distance is equal to 0 (we have evaluated distance between a venue and itself)
# 2. Rows where distance is greater than 200 meters
#
# After that we sort the values in descending order, in order to find the top venues located near Italian Restaurants

# %%
restaurant_venues_mod = restaurant_venues[restaurant_venues['Distance'] != 0] #remove 0 distance rows
restaurant_venues_mod200 = restaurant_venues_mod[restaurant_venues['Distance'] < 0.2] #keep only the venues up to 200 meters
restaurant_venues_mod200.head()
# Out:
# C:\Users\flavio.burri\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#              Restaurant             Venue type  Restaurant longitude  \
# 67   Italian Restaurant            Coffee Shop            -79.387664
# 68   Italian Restaurant  Portuguese Restaurant            -79.387664
# 80   Italian Restaurant    Fried Chicken Joint            -79.387664
# 93   Italian Restaurant            Coffee Shop            -79.387664
# 459  Italian Restaurant            Coffee Shop            -79.387664
#
#      Restaurant latitude  Venue longitude  Venue latitude  Distance
# 67             43.660391       -79.385830       43.660130  0.150376
# 68             43.660391       -79.386391       43.661728  0.180543
# 80             43.660391       -79.389475       43.659167  0.199350
# 93             43.660391       -79.388696       43.658906  0.184787
# 459            43.660391       -79.385830       43.660130  0.150376

# %%
restaurant_venues_mod200.shape
# Out:
# (1062, 7)

# %%
restaurant_venues_mod200_sorted = restaurant_venues_mod200.groupby('Venue type').count().sort_values(['Distance'], ascending=[False])
restaurant_venues_mod200_sorted
# Out:
#                                  Restaurant  Restaurant longitude  \
# Venue type
# Coffee Shop                             134                   134
# Restaurant                               61                    61
# Hotel                                    54                    54
# Italian Restaurant                       46                    46
# Café                                     42                    42
# Cocktail Bar                             39                    39
# Gastropub                                38                    38
# Gym                                      33                    33
# Beer Bar                                 32                    32
# Japanese Restaurant                      32                    32
# Thai Restaurant                          29                    29
# Park                                     23                    23
# Fountain                                 16                    16
# Clothing Store                           16                    16
# Creperie                                 15                    15
# Cosmetics Shop                           15                    15
# Poke Place                               14                    14
# Food Truck                               12                    12
# Jazz Club                                12                    12
# French Restaurant                        12                    12
# Concert Hall                             11                    11
# Department Store                         11                    11
# Pub                                      11                    11
# Pizza Place                              11                    11
# Yoga Studio                              11                    11
# Greek Restaurant                         11                    11
# Comfort Food Restaurant                  10                    10
# Tailor Shop                              10                    10
# Vegetarian / Vegan Restaurant            10                    10
# Sushi Restaurant                          9                     9
# Furniture / Home Store                    9                     9
# Breakfast Spot                            9                     9
# Bookstore                                 9                     9
# Train Station                             9                     9
# Bakery                                    9                     9
# Sandwich Place                            8                     8
# Indian Restaurant                         8                     8
# Dessert Shop                              8                     8
# Hostel                                    7                     7
# Molecular Gastronomy Restaurant           7                     7
# Portuguese Restaurant                     6                     6
# Bar                                       6                     6
# Juice Bar                                 5                     5
# Wine Bar                                  5                     5
# Bubble Tea Shop                           5                     5
# Steakhouse                                5                     5
# Church                                    5                     5
# Bistro                                    5                     5
# Modern European Restaurant                4                     4
# Fast Food Restaurant                      4                     4
# Gym / Fitness Center                      4                     4
# Spa                                       4                     4
# Bank                                      4                     4
# Seafood Restaurant                        4                     4
# Moroccan Restaurant                       4                     4
# Pet Store                                 4                     4
# Pharmacy                                  4                     4
# Lingerie Store                            4                     4
# Plaza                                     4                     4
# Fried Chicken Joint                       4                     4
# Diner                                     4                     4
# Discount Store                            4                     4
# Liquor Store                              3                     3
# Toy / Game Store                          3                     3
# New American Restaurant                   3                     3
# Electronics Store                         3                     3
# Ice Cream Shop                            3                     3
# Nightclub                                 3                     3
# Grocery Store                             3                     3
# Gift Shop                                 3                     3
# Chinese Restaurant                        3                     3
# Salad Place                               3                     3
# Music Venue                               2                     2
# Noodle House                              2                     2
# Movie Theater                             2                     2
# Roof Deck                                 2                     2
# Mexican Restaurant                        2                     2
# Office                                    2                     2
# IT Services                               2                     2
# Butcher                                   2                     2
# Lounge                                    2                     2
# Asian Restaurant                          2                     2
# Beer Store                                2                     2
# Deli / Bodega                             2                     2
# Belgian Restaurant                        2                     2
# Burger Joint                              2                     2
# Brewery                                   2                     2
# Frozen Yogurt Shop                        2                     2
# Gas Station                               2                     2
# Taiwanese Restaurant                      1                     1
# Sporting Goods Shop                       1                     1
# Stadium                                   1                     1
# Burrito Place                             1                     1
# Supermarket                               1                     1
# Men's Store                               1                     1
# Tanning Salon                             1                     1
# Shopping Mall                             1                     1
# Bike Shop                                 1                     1
# Theater                                   1                     1
# Trail                                     1                     1
# Video Game Store                          1                     1
# Vietnamese Restaurant                     1                     1
# Arts & Crafts Store                       1                     1
# Tea Room                                  1                     1
# College Gym                               1                     1
# Shoe Store                                1                     1
# Health Food Store                         1                     1
# Market                                    1                     1
# Kitchen Supply Store                      1                     1
# Jewelry Store                             1                     1
# Intersection                              1                     1
# Neighborhood                              1                     1
# Indie Movie Theater                       1                     1
# Antique Shop                              1                     1
# Hotel Bar                                 1                     1
# General Entertainment                     1                     1
# Caribbean Restaurant                      1                     1
# Gay Bar                                   1                     1
# Fruit & Vegetable Store                   1                     1
# Eastern European Restaurant               1                     1
# Distribution Center                       1                     1
# Dim Sum Restaurant                        1                     1
# Cuban Restaurant                          1                     1
# Convenience Store                         1                     1
# Middle Eastern Restaurant                 1                     1
# Beer Store                                    2         2
# Deli / Bodega                                 2         2
# Belgian Restaurant                            2         2
# Burger Joint                                  2         2
# Brewery                                       2         2
# Frozen Yogurt Shop                            2         2
# Gas Station                                   2         2
# Taiwanese Restaurant                          1         1
# Sporting Goods Shop                           1         1
# Stadium                                       1         1
# Burrito Place                                 1         1
# Supermarket                                   1         1
# Men's Store                                   1         1
# Tanning Salon                                 1         1
# Shopping Mall                                 1         1
# Bike Shop                                     1         1
# Theater                                       1         1
# Trail                                         1         1
# Video Game Store                              1         1
# Vietnamese Restaurant                         1         1
# Arts & Crafts Store                           1         1
# Tea Room                                      1         1
# College Gym                                   1         1
# Shoe Store                                    1         1
# Health Food Store                             1         1
# Market                                        1         1
# Kitchen Supply Store                          1         1
# Jewelry Store                                 1         1
# Intersection                                  1         1
# Neighborhood                                  1         1
# Indie Movie Theater                           1         1
# Antique Shop                                  1         1
# Hotel Bar                                     1         1
# General Entertainment                         1         1
# Caribbean Restaurant                          1         1
# Gay Bar                                       1         1
# Fruit & Vegetable Store                       1         1
# Eastern European Restaurant                   1         1
# Distribution Center                           1         1
# Dim Sum Restaurant                            1         1
# Cuban Restaurant                              1         1
# Convenience Store                             1         1
# Middle Eastern Restaurant                     1         1
# American Restaurant                           1         1

# %% [markdown]
# ##### We want to select only the venues that are not restaurants.
# The first three venues are:
#
# 1. Coffee Shop
# 2. Bar
# 3. Hotel
#
# We will use those three to better define where to open the restaurant.

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighbourhood column back to dataframe
toronto_onehot['Postal Code'] = toronto_venues_it_rest['Postal Code']
toronto_onehot['Neighbourhood Latitude'] = toronto_venues_it_rest['Neighbourhood Latitude'] 
toronto_onehot['Neighbourhood Longitude'] = toronto_venues_it_rest['Neighbourhood Longitude'] 

# move neighbourhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_onehot_italian = toronto_onehot[toronto_onehot['Italian Restaurant'] != 0]
toronto_onehot_italian.reset_index()
toronto_onehot_italian.head()
# Out:
#      Neighbourhood Longitude  Accessories Store  Afghan Restaurant  Airport  \
# 66                -79.389494                  0                  0        0
# 163               -79.378937                  0                  0        0
# 181               -79.378937                  0                  0        0
# 222               -79.340923                  0                  0        0
# 254               -79.375418                  0                  0        0
#
#      Airport Food Court  Airport Gate  Airport Lounge  Airport Service  \
# 66                    0             0               0                0
# 163                   0             0               0                0
# 181                   0             0               0                0
# 222                   0             0               0                0
# 254                   0             0               0                0
#
#      Airport Terminal  American Restaurant  Antique Shop  Aquarium  \
# 66                  0                    0             0         0
# 163                 0                    0             0         0
# 181                 0                    0             0         0
# 222                 0                    0             0         0
# 254                 0                    0             0         0
#
#      Art Gallery  Art Museum  Arts & Crafts Store  Asian Restaurant  \
# 66             0           0                    0                 0
# 163            0           0                    0                 0
# 181            0           0                    0                 0
# 222            0           0                    0                 0
# 254            0           0                    0                 0
#
#      Athletics & Sports  Auto Garage  Auto Workshop  BBQ Joint  Baby Store  \
# 66                    0            0              0          0           0
# 163                   0            0              0          0           0
# 181                   0            0              0          0           0
# 222                   0            0              0          0           0
# 254                   0            0              0          0           0
#
#      Bagel Shop  Bakery  Bank  Bar  Baseball Field  Baseball Stadium  \
# 66            0       0     0    0               0                 0
# 163           0       0     0    0               0                 0
# 181           0       0     0    0               0                 0
# 222           0       0     0    0               0                 0
# 254           0       0     0    0               0                 0
#
#      Basketball Stadium  Beach  Bed & Breakfast  Beer Bar
italian_restaurant_map = folium.Map(location=[latitude, longitude], zoom_start=13)

# instantiate a mark cluster object for the incidents in the dataframe
italian_restaurant = plugins.MarkerCluster().add_to(italian_restaurant_map)

# add markers to map
for lat, lng, label in zip(toronto_onehot_italian['Neighbourhood Latitude'], toronto_onehot_italian['Neighbourhood Longitude'], toronto_onehot_italian['Postal Code']):
    label = '{}'.format(label)
    label = folium.Popup(label, parse_html=True)
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(italian_restaurant)
    
italian_restaurant_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# As we can see from these data, 21 Italian Restaurants may be found between Toronto Union Station and the University of Toronto. This probably means that this is one of the most frequented zone in Toronto, therefore this is one of the best place  where to open an Italian Restaurant.
#
# We can then use the data about the other venues near Italian Restaurants to better define the area on which focus our attention.

# %% [markdown]
# ##### Quering Foursquare and cleaning the data obtained

# %%
search_query = 'Italian Restaurant'
radius = 50000
#print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=PUR3VSJFUQSEHZ3MKTY5OLTU5OJG4NMFKP2WBGIGFJXG10RS&client_secret=THK4KZ2T2BQVWMIPVJFWDMOGYR4SO5XZ5UD5FEPZP0P35LDP&ll=43.6534817,-79.3839347&v=20180604&query=Italian Restaurant&radius=50000&limit=10000'

# %% [markdown]
# And check the obtained dataframe

# %%
results = requests.get(url).json()
# assign relevant part of JSON to venues
venues = results['response']['venues']
# tranform venues into a dataframe
dataframe = json_normalize(venues)
#dataframe.drop(dataframe[(dataframe['location.postalCode'] == 'NaN')].index(), inplace=True)

dataframe.shape
# Out:
# (50, 19)

# %%
dataframe
# Out:
#                                            categories  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 1   [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 2   [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 3   [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 4   [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 5   [{'id': '56aa371be4b08b9a8d573550', 'name': 'F...    False
# 6                                                  []    False
# 7   [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 8   [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 9                                                  []    False
# 10  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 11  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 12  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 13  [{'id': '4bf58dd8d48988d12c951735', 'name': 'E...    False
# 14  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 15  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...    False
# 16  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 17  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 18  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 19  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 20  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 21  [{'id': '52af3b773cf9994f4e043c03', 'name': 'S...    False
# 22  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...    False
# 23  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
# 24  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 25  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
# 26  [{'id': '4bf58dd8d48988d157941735', 'name': 'N...    False
# 27  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...    False
# 28  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 29  [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...    False
# 30  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...    False
# 31  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...    False
# 32  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 33  [{'id': '56aa371be4b08b9a8d573538', 'name': 'T...    False
# 34  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...    False
# 35  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 36  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 37  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 38  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
# 39  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 40  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 41  [{'id': '4bf58dd8d48988d1c9941735', 'name': 'I...    False
# 42  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...    False
# 43  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 44  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 45  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 46  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...    False
# 47  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 48  [{'id': '4bf58dd8d48988d147941735', 'name': 'D...    False
# 49  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
#
#                           id                 location.address location.cc  \
# 0   4e74ce151838f918898efe72                  6350 Tomken Rd.          CA
# 1   4de024f0b0fbe2cfa5fee3c4                              NaN          CA
# 2   4b4f6a73f964a520960527e3                24-40 Bradwick Dr          CA
# 3   4b199b46f964a5205be023e3                      2625 Weston          CA
# 4   4b107754f964a520147123e3              4505 Sheppard Ave E          CA
# 5   55e549c8498ea9b7acd67e8b                6720 Davand Drive          CA
# 6   4d5577519e508cfa9c72009b                  Derry Road West          CA
# 7   4c7d330c5af8b60cb8d38e10                              NaN          CA
# 8   4e24ce2bd164e1d5a512bfe6                              NaN          CA
# 9   4b53882ef964a5200fa127e3                              NaN          CA
# 10  55bcde11498e244a3a859792                      438 Kerr St          CA
# 10      Oakville           Canada                                 NaN
# 11           NaN           Canada                                 NaN
# 12       Toronto           Canada                                 NaN
# 13       Toronto           Canada                       Dundas Street
# 14       Toronto           Canada                             Gerrard
# 15       Toronto           Canada                                 NaN
# 16       Toronto           Canada                                 NaN
# 17    Burlington           Canada                                 NaN
# 18       Toronto           Canada                                 NaN
# 19       Toronto           Canada                           Dundas St
# 20       Toronto           Canada                                 NaN
# 21       Toronto           Canada                                 NaN
# 22       Toronto           Canada                                 NaN
# 23       Toronto           Canada                                 NaN
# 24           NaN           Canada                                 NaN
# 25       Toronto           Canada                   at University Ave
# 26           NaN           Canada                      University Ave
# 27           NaN           Canada                                 NaN
# 28       Toronto           Canada                                 NaN
# 29       Toronto           Canada                         at Chestnut
# 30       Toronto           Canada                      at Carlton St.
# 31       Toronto           Canada             north of Carlton Street
# 32       Toronto           Canada                  Dundas Street West
# 33       Toronto           Canada                                 NaN
# 34       Toronto           Canada                          College St
# 35           NaN           Canada                                 NaN
# 36       Toronto           Canada    at Le Meridien King Edward Hotel
# 37       Toronto           Canada                                 NaN
# 38       Toronto           Canada                               Huron
# 39       Toronto           Canada             Richmond and Bay Street
# 40       Toronto           Canada                          at Bay St.
# 41       Toronto           Canada             btwn Avenue Rd & Bay St
# 42       Toronto           Canada                                 NaN
# 43       Toronto           Canada                            Queen St
# 44       Toronto           Canada                               Yonge
# 45       Toronto           Canada                                 NaN
# 46       Toronto           Canada                          at John St
# 47       Toronto           Canada  in InterContinental Toronto Centre
# 48       Toronto           Canada                   at Ossington Ave.
# 49       Toronto           Canada                                 NaN
#
#     location.distance                          location.formattedAddress  \
# 0               22882  [6350 Tomken Rd. (Tristar), Mississauga ON, Ca...
# 1                3430                               [Toronto ON, Canada]
# 2               20061  [24-40 Bradwick Dr (btw Keele St. & Dufferin S...
# 3               13546            [2625 Weston (401), Toronto ON, Canada]
# 4               17771  [4505 Sheppard Ave E, Scarborough ON M1S 1V3, ...
# 5               22923  [6720 Davand Drive, Mississauga ON L5T 2K7, Ca...
# 6               21855          [Derry Road West, Mississauga ON, Canada]
# 7               23522                                           [Canada]
# 8               27669                                  [Ontario, Canada]
# 9               32412                                           [Canada]
# 10              33529         [438 Kerr St, Oakville ON L6K 3C4, Canada]
# 11              36962                                           [Canada]
# 12                726   [66 Wellington St W, Toronto ON M5K 1E7, Canada]
# 13                821  [136 Beverley St (Dundas Street), Toronto ON, ...
# 14                611  [382 Yonge Street, Unit #7 (Gerrard), Toronto ...
# 15                271                   [CNE Midway, Toronto ON, Canada]
# 16                482        [15 Elm Street, Toronto ON M5G 1G7, Canada]
# 17              49531  [1477 Lakeshore Rd, Burlington ON L7S 1B5, Can...
# 18                224  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 19                304  [595 Bay St (Dundas St), Toronto ON M5G 2C2, C...
# 20                360                               [Toronto ON, Canada]
# 21                839           [988 Baldwin Street, Toronto ON, Canada]
# 22                242      [124 Chestnut St, Toronto ON M5G 1R3, Canada]
# 23               1098  [261 Spadina Avenue. Upper level, Toronto ON M...
# 24                331                                           [Canada]
# 25                300  [195 Dundas St W (at University Ave), Toronto ...
# 26                189  [130 Queen St W (University Ave), M5H 2N6, Can...
# 27                279                                           [Canada]
# 28                284  [67 Richmond St West, Toronto ON M5H 1W2, Canada]
# 29                264  [179 Dundas St. W. (at Chestnut), Toronto ON M...
# 30                966  [389 Church St. (at Carlton St.), Toronto ON M...
# 31               1179  [338 Jarvis St. (north of Carlton Street), Tor...
# 32                553  [109 McCaul Street, Unit #42 (Dundas Street We...
# 33                294  [40 Dundas St W Box 36,, Toronto ON M5G 2C2, C...
# 34               1287  [405 Spadina Ave (College St), Toronto ON M5T ...
# 35                352                                           [Canada]
# 36                763  [37 King Street East (at Le Meridien King Edwa...
# 37                809            [27 Baldwin Street, Toronto ON, Canada]
# 38               1026       [476 Dundas St. (Huron), Toronto ON, Canada]
# 39                315  [67 Richmond Street West (Richmond and Bay Str...
# 40                242  [108 Dundas St W (at Bay St.), Toronto ON M5G ...
# 41               1962  [146 Cumberland St (btwn Avenue Rd & Bay St), ...
# 42               1719               [566 Queen St W, Toronto ON, Canada]
# 43                341  [Yonge And Queen (Queen St), Toronto ON M5G 2H...
# 44               2061  [17 Yorkville Ave. (Yonge), Toronto ON M4W 1L1...
# 45               1389                [Rogers Centre, Toronto ON, Canada]
# 46               1048  [30 Mercer Street (at John St), Toronto ON M5V...
# 47                976  [225 Front St W (in InterContinental Toronto C...
# 48               2970  [1132 Dundas St. W (at Ossington Ave.), Toront...
# 49                303       [56 Centre Ave., Toronto ON M5G 1R5, Canada]
#
#                               location.labeledLatLngs  location.lat  \
# 0   [{'label': 'display', 'lat': 43.65285913569359...     43.652859
# 1   [{'label': 'display', 'lat': 43.67656199554484...     43.676562
# 2   [{'label': 'display', 'lat': 43.8182382, 'lng'...     43.818238
# 3   [{'label': 'display', 'lat': 43.71194605276710...     43.711946
# 4   [{'label': 'display', 'lat': 43.788071, 'lng':...     43.788071
# 5   [{'label': 'display', 'lat': 43.66758, 'lng': ...     43.667580
# 6   [{'label': 'display', 'lat': 43.703068, 'lng':...     43.703068
# 7   [{'label': 'display', 'lat': 43.68860510830914...     43.688605
# 8   [{'label': 'display', 'lat': 43.88753489635225...     43.887535
# 9   [{'label': 'display', 'lat': 43.44640202412109...     43.446402
# 10  [{'label': 'display', 'lat': 43.44530127192647...     43.445301
# 11  [{'label': 'display', 'lat': 43.853653, 'lng':...     43.853653
# 12  [{'label': 'display', 'lat': 43.647161, 'lng':...     43.647161
# 13  [{'label': 'display', 'lat': 43.65402694219784...     43.654027
# 14  [{'label': 'display', 'lat': 43.65892029202872...     43.658920
# 15  [{'label': 'display', 'lat': 43.652144, 'lng':...     43.652144
# 16  [{'label': 'display', 'lat': 43.65769, 'lng': ...     43.657690
# 17  [{'label': 'display', 'lat': 43.32437, 'lng': ...     43.324370
# 18  [{'label': 'display', 'lat': 43.65488413420439...     43.654884
# 19  [{'label': 'display', 'lat': 43.65616, 'lng': ...     43.656160
# 20  [{'label': 'display', 'lat': 43.65499143746528...     43.654991
# 21  [{'label': 'display', 'lat': 43.655874, 'lng':...     43.655874
# 22  [{'label': 'display', 'lat': 43.655165, 'lng':...     43.655165
# 23  [{'label': 'display', 'lat': 43.65248783033554...     43.652488
# 24  [{'label': 'display', 'lat': 43.65053979517576...     43.650540
# 25  [{'label': 'display', 'lat': 43.65492521335936...     43.654925
# 26  [{'label': 'display', 'lat': 43.65197895903515...     43.651979
# 27  [{'label': 'display', 'lat': 43.65472793579101...     43.654728
# 28  [{'label': 'display', 'lat': 43.6513954168839,...     43.651395
# 29  [{'label': 'display', 'lat': 43.65506808, 'lng...     43.655068
# 30  [{'label': 'display', 'lat': 43.66150015906530...     43.661500
# 31  [{'label': 'display', 'lat': 43.66277006654972...     43.662770
# 32  [{'label': 'display', 'lat': 43.653889, 'lng':...     43.653889
# 33  [{'label': 'display', 'lat': 43.65610515821675...     43.656105
# 34  [{'label': 'display', 'lat': 43.656794, 'lng':...     43.656794
# 35  [{'label': 'display', 'lat': 43.65610066909799...     43.656101
# 36  [{'label': 'display', 'lat': 43.64929834396347...     43.649298
# 37  [{'label': 'display', 'lat': 43.65612672798775...     43.656127
# 38  [{'label': 'display', 'lat': 43.6531846832903,...     43.653185
# 39  [{'label': 'display', 'lat': 43.65109052088520...     43.651091
# 40  [{'label': 'display', 'lat': 43.65565507065502...     43.655655
# 41  [{'label': 'display', 'lat': 43.66995452843031...     43.669955
# 42  [{'label': 'display', 'lat': 43.64728932229506...     43.647289
# 43  [{'label': 'display', 'lat': 43.65341542752959...     43.653415
# 44  [{'label': 'display', 'lat': 43.67168516880110...     43.671685
# 45  [{'label': 'display', 'lat': 43.64163507221119...     43.641635
# 46  [{'label': 'display', 'lat': 43.64563436248102...     43.645634
# 47  [{'label': 'display', 'lat': 43.64474919591934...     43.644749
# 48  [{'label': 'display', 'lat': 43.64943515996231...     43.649435
# 49  [{'label': 'display', 'lat': 43.65483285234745...     43.654833
#
#     location.lng   location.neighborhood location.postalCode location.state  \
# 0     -79.668040                     NaN                 NaN             ON
# 1     -79.355699                     NaN                 NaN             ON
# 2     -79.485024                     NaN             L4K 1K9             ON
# 3     -79.531510                     NaN                 NaN             ON
# 4     -79.265134                     NaN             M1S 1V3             ON
# 5     -79.667920                     NaN             L5T 2K7             ON
# 6     -79.646597                     NaN                 NaN             ON
# 7     -79.672008                     NaN                 NaN            NaN
# 8     -79.499824                     NaN                 NaN        Ontario
# 9     -79.666352                     NaN                 NaN            NaN
# 10    -79.684267                     NaN             L6K 3C4             ON
# 11    -79.017173                     NaN                 NaN            NaN
# 12    -79.381691                     NaN             M5K 1E7             ON
# 13    -79.394104                     NaN                 NaN             ON
# 14    -79.382891                     NaN             M5B 1S8             ON
# 15    -79.381118                     NaN                 NaN             ON
# 16    -79.382480                     NaN             M5G 1G7             ON
# 17    -79.796670                     NaN             L7S 1B5             ON
# 18    -79.385931                     NaN             M5G 1R3             ON
# 19    -79.383190                     NaN             M5G 2C2             ON
# 20    -79.387897                     NaN                 NaN             ON
# 21    -79.393826                     NaN                 NaN             ON
# 22    -79.385847                     NaN             M5G 1R3             ON
# 27             Castries Bar & Five Way Restaurant  v-1607940955          NaN
# 28                               Maezo Restaurant  v-1607940955          NaN
# 29                                Cali Restaurant  v-1607940955          NaN
# 30                              Studio Restaurant  v-1607940955          NaN
# 31                    Cottage Restaurant & Lounge  v-1607940955          NaN
# 32                       The Fresh Italian Eatery  v-1607940955          NaN
# 33  Spring Rolls | Japanese Restaurant in Toronto  v-1607940955          NaN
# 34        Tasty's Caribbean Restaurant & Catering  v-1607940955          NaN
# 35                  Terrace Restaurant at Elmwood  v-1607940955          NaN
# 36                          Victoria's Restaurant  v-1607940955    498556908
# 37                            john's italian cafe  v-1607940955          NaN
# 38             North-East Chinese Restaurant 華北美食  v-1607940955          NaN
# 39                         Maezo Restaurant & Bar  v-1607940955    369067217
# 40                     Alio Restaurant & Wine Bar  v-1607940955          NaN
# 41                   Punto Gelato, Simply Italian  v-1607940955          NaN
# 42                  Micheal's Restaurant and Deli  v-1607940955          NaN
# 43                     Hendricks Restaurant & Bar  v-1607940955          NaN
# 44                      Blu Ristorante and Lounge  v-1607940955          NaN
# 45                          Sightlines Restaurant  v-1607940955          NaN
# 46                        Victor Restaurant & Bar  v-1607940955          NaN
# 47                         Azure Restaurant & Bar  v-1607940955    136175835
# 48                        The Lakeview Restaurant  v-1607940955          NaN
# 49                     Wah Too Seafood Restaurant  v-1607940955          NaN

# %% [markdown]
# As we can see, the name of the columns are not user friendly, so we work a bit on this dataframe to change the column names.

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                               name           categories              address  \
# 0          Roma Italian Restaurant    Indian Restaurant      6350 Tomken Rd.
# 1  Florentina's Italian Restaurant   Italian Restaurant                  NaN
# 2      Junnio's Italian Restaurant           Restaurant    24-40 Bradwick Dr
# 3      Jolly II Italian Restaurant   Italian Restaurant          2625 Weston
# 4  Joey Bravo's Italian Restaurant  American Restaurant  4505 Sheppard Ave E
#
#    cc         city country                   crossStreet  distance  \
# 0  CA  Mississauga  Canada                       Tristar     22882
# 1  CA      Toronto  Canada                           NaN      3430
# 2  CA      Vaughan  Canada  btw Keele St. & Dufferin St.     20061
# 3  CA      Toronto  Canada                           401     13546
# 4  CA  Scarborough  Canada                           NaN     17771
#
#                                     formattedAddress  \
# 0  [6350 Tomken Rd. (Tristar), Mississauga ON, Ca...
# 1                               [Toronto ON, Canada]
# 2  [24-40 Bradwick Dr (btw Keele St. & Dufferin S...
# 3            [2625 Weston (401), Toronto ON, Canada]
# 4  [4505 Sheppard Ave E, Scarborough ON M1S 1V3, ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65285913569359...  43.652859 -79.668040
# 1  [{'label': 'display', 'lat': 43.67656199554484...  43.676562 -79.355699
# 2  [{'label': 'display', 'lat': 43.8182382, 'lng'...  43.818238 -79.485024
# 3  [{'label': 'display', 'lat': 43.71194605276710...  43.711946 -79.531510
# 4  [{'label': 'display', 'lat': 43.788071, 'lng':...  43.788071 -79.265134
#
#   neighborhood postalCode state                        id
# 0          NaN        NaN    ON  4e74ce151838f918898efe72
# 1          NaN        NaN    ON  4de024f0b0fbe2cfa5fee3c4
# 2          NaN    L4K 1K9    ON  4b4f6a73f964a520960527e3
# 3          NaN        NaN    ON  4b199b46f964a5205be023e3
# 4          NaN    M1S 1V3    ON  4b107754f964a520147123e3

# %% [markdown]
# We create a new column named "Postcode" that will be used for the graphics.

# %%
#Keep only first 3 of Postcode
dataframe_filtered['Postcode'] = dataframe_filtered['postalCode'].str[:3]
dataframe_filtered.head()
# Out:
#                               name           categories              address  \
# 0          Roma Italian Restaurant    Indian Restaurant      6350 Tomken Rd.
# 1  Florentina's Italian Restaurant   Italian Restaurant                  NaN
# 2      Junnio's Italian Restaurant           Restaurant    24-40 Bradwick Dr
# 3      Jolly II Italian Restaurant   Italian Restaurant          2625 Weston
# 4  Joey Bravo's Italian Restaurant  American Restaurant  4505 Sheppard Ave E
#
#    cc         city country                   crossStreet  distance  \
# 0  CA  Mississauga  Canada                       Tristar     22882
# 1  CA      Toronto  Canada                           NaN      3430
# 2  CA      Vaughan  Canada  btw Keele St. & Dufferin St.     20061
# 3  CA      Toronto  Canada                           401     13546
# 4  CA  Scarborough  Canada                           NaN     17771
#
#                                     formattedAddress  \
# 0  [6350 Tomken Rd. (Tristar), Mississauga ON, Ca...
# 1                               [Toronto ON, Canada]
# 2  [24-40 Bradwick Dr (btw Keele St. & Dufferin S...
# 3            [2625 Weston (401), Toronto ON, Canada]
# 4  [4505 Sheppard Ave E, Scarborough ON M1S 1V3, ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65285913569359...  43.652859 -79.668040
# 1  [{'label': 'display', 'lat': 43.67656199554484...  43.676562 -79.355699
# 2  [{'label': 'display', 'lat': 43.8182382, 'lng'...  43.818238 -79.485024
# 3  [{'label': 'display', 'lat': 43.71194605276710...  43.711946 -79.531510
# 4  [{'label': 'display', 'lat': 43.788071, 'lng':...  43.788071 -79.265134
#
#   neighborhood postalCode state                        id Postcode
# 0          NaN        NaN    ON  4e74ce151838f918898efe72      NaN
# 1          NaN        NaN    ON  4de024f0b0fbe2cfa5fee3c4      NaN
# 2          NaN    L4K 1K9    ON  4b4f6a73f964a520960527e3      L4K
# 3          NaN        NaN    ON  4b199b46f964a5205be023e3      NaN
# 4          NaN    M1S 1V3    ON  4b107754f964a520147123e3      M1S

# %% [markdown]
# We now check the data obtained

# %%
dataframe_filtered.groupby('categories').count()
# Out:
#                          name  address  cc  city  country  crossStreet  \
# categories
# American Restaurant         4        3   4     3        4            0
# Asian Restaurant            1        1   1     1        1            0
# Bar                         2        2   2     2        2            1
# Breakfast Spot              1        1   1     1        1            1
# Caribbean Restaurant        2        1   2     1        2            1
# Chinese Restaurant          4        4   4     4        4            2
# Diner                       1        1   1     1        1            1
# Embassy / Consulate         1        1   1     1        1            1
# Food Service                1        1   1     1        1            0
# Food Truck                  1        1   1     1        1            0
# Ice Cream Shop              1        1   1     1        1            1
# Indian Restaurant           3        3   3     3        3            2
# Italian Restaurant         17       11  17    13       17            6
# New American Restaurant     1        1   1     0        1            1
# Restaurant                  4        4   4     4        4            4
# Szechuan Restaurant         1        1   1     1        1            0
# Thai Restaurant             1        1   1     1        1            1
# Theme Restaurant            1        1   1     1        1            0
# 0                           NaN  CA     Toronto  Canada                 NaN
# 1                   2625 Weston  CA     Toronto  Canada                 401
# 2                           NaN  CA         NaN  Canada                 NaN
# 3                           NaN  CA         NaN  Canada                 NaN
# 4                   438 Kerr St  CA    Oakville  Canada                 NaN
# 5                           NaN  CA         NaN  Canada                 NaN
# 6            66 Wellington St W  CA     Toronto  Canada                 NaN
# 7     382 Yonge Street, Unit #7  CA     Toronto  Canada             Gerrard
# 8                 15 Elm Street  CA     Toronto  Canada                 NaN
# 9             1477 Lakeshore Rd  CA  Burlington  Canada                 NaN
# 10                   595 Bay St  CA     Toronto  Canada           Dundas St
# 11                          NaN  CA     Toronto  Canada                 NaN
# 12                          NaN  CA         NaN  Canada                 NaN
# 13  109 McCaul Street, Unit #42  CA     Toronto  Canada  Dundas Street West
# 14            27 Baldwin Street  CA     Toronto  Canada                 NaN
# 15              108 Dundas St W  CA     Toronto  Canada          at Bay St.
# 16            17 Yorkville Ave.  CA     Toronto  Canada               Yonge
#
#     distance                                   formattedAddress  \
# 0       3430                               [Toronto ON, Canada]
# 1      13546            [2625 Weston (401), Toronto ON, Canada]
# 2      23522                                           [Canada]
# 3      27669                                  [Ontario, Canada]
# 4      33529         [438 Kerr St, Oakville ON L6K 3C4, Canada]
# 5      36962                                           [Canada]
# 6        726   [66 Wellington St W, Toronto ON M5K 1E7, Canada]
# 7        611  [382 Yonge Street, Unit #7 (Gerrard), Toronto ...
# 8        482        [15 Elm Street, Toronto ON M5G 1G7, Canada]
# 9      49531  [1477 Lakeshore Rd, Burlington ON L7S 1B5, Can...
# 10       304  [595 Bay St (Dundas St), Toronto ON M5G 2C2, C...
# 11       360                               [Toronto ON, Canada]
# 12       331                                           [Canada]
# 13       553  [109 McCaul Street, Unit #42 (Dundas Street We...
# 14       809            [27 Baldwin Street, Toronto ON, Canada]
# 15       242  [108 Dundas St W (at Bay St.), Toronto ON M5G ...
# 16      2061  [17 Yorkville Ave. (Yonge), Toronto ON M4W 1L1...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 43.67656199554484...  43.676562 -79.355699
# 1   [{'label': 'display', 'lat': 43.71194605276710...  43.711946 -79.531510
# 2   [{'label': 'display', 'lat': 43.68860510830914...  43.688605 -79.672008
# 3   [{'label': 'display', 'lat': 43.88753489635225...  43.887535 -79.499824
# 4   [{'label': 'display', 'lat': 43.44530127192647...  43.445301 -79.684267
# 5   [{'label': 'display', 'lat': 43.853653, 'lng':...  43.853653 -79.017173
# 6   [{'label': 'display', 'lat': 43.647161, 'lng':...  43.647161 -79.381691
# 7   [{'label': 'display', 'lat': 43.65892029202872...  43.658920 -79.382891
# 8   [{'label': 'display', 'lat': 43.65769, 'lng': ...  43.657690 -79.382480
# 9   [{'label': 'display', 'lat': 43.32437, 'lng': ...  43.324370 -79.796670
# 10  [{'label': 'display', 'lat': 43.65616, 'lng': ...  43.656160 -79.383190
# 11  [{'label': 'display', 'lat': 43.65499143746528...  43.654991 -79.387897
# 12  [{'label': 'display', 'lat': 43.65053979517576...  43.650540 -79.384603
# 13  [{'label': 'display', 'lat': 43.653889, 'lng':...  43.653889 -79.390785
# 14  [{'label': 'display', 'lat': 43.65612672798775...  43.656127 -79.393301
# 15  [{'label': 'display', 'lat': 43.65565507065502...  43.655655 -79.384124
# 16  [{'label': 'display', 'lat': 43.67168516880110...  43.671685 -79.388614
#
#    neighborhood postalCode    state                        id Postcode
# 0           NaN        NaN       ON  4de024f0b0fbe2cfa5fee3c4      NaN
# 1           NaN        NaN       ON  4b199b46f964a5205be023e3      NaN
# 2           NaN        NaN      NaN  4c7d330c5af8b60cb8d38e10      NaN
# 3           NaN        NaN  Ontario  4e24ce2bd164e1d5a512bfe6      NaN
# 4           NaN    L6K 3C4       ON  55bcde11498e244a3a859792      L6K
# 5           NaN        NaN      NaN  4c9a4464a004a1cd97de466e      NaN
# 6           NaN    M5K 1E7       ON  5b897e92db1d81002c91df8c      M5K
# 7           NaN    M5B 1S8       ON  52f6816f11d24a43115dc834      M5B
# 8           NaN    M5G 1G7       ON  5e594c8a3de308000870c948      M5G
# 9           NaN    L7S 1B5       ON  5b394376c66666002c5e54ef      L7S
# 10          NaN    M5G 2C2       ON  573df789498e03dd8e54b166      M5G
# 11          NaN        NaN       ON  51bf3866498e55ee55df8db0      NaN
# 12          NaN        NaN      NaN  4f88cf84e4b002b90ab3b9b9      NaN
# 13          NaN    M5T 3K5       ON  526fe29411d2aeb3803013b0      M5T
# 14          NaN        NaN       ON  53daae5b498e9c9597c19b23      NaN
# 15          NaN    M5G 1C3       ON  4ae9ef82f964a520cbb721e3      M5G
# 16          NaN    M4W 1L1       ON  4b737d37f964a520f6b02de3      M4W

# %% [markdown]
# ##### Creating Marcker Cluster Maps to focus on analysis
# Now let's use the data we have to create a Marker Cluster map to see where to focus our attention in the data analysis.

# %%
from folium import plugins
italian_restaurant_map = folium.Map(location=[latitude, longitude], zoom_start=14)

# instantiate a mark cluster object for the incidents in the dataframe
#italian_restaurant_df_marker = plugins.MarkerCluster().add_to(italian_restaurant_map)

# add markers to map
for lat, lng, label in zip(italian_restaurant_df['lat'], italian_restaurant_df['lng'], italian_restaurant_df['name']):
    label = '{}'.format(label)
    label = folium.Popup(label, parse_html=True)
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(italian_restaurant_map)
    
italian_restaurant_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# From this graphic we see that the majority of the Italian Restaurants are located between Toronto Union Station and college street.

# %% [markdown]
# Now we check if the top venues that are commonly found around Italian Restaurants can help us in defining interesting areas

# %%
#First search: Coffee Shop
search_query = 'Coffee Shop'
radius = 50000

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

coffee_shop = requests.get(url).json()
# assign relevant part of JSON to venues
venues_coffee_shop = coffee_shop['response']['venues']
# tranform venues into a dataframe
coffee_shop = json_normalize(venues_coffee_shop)
#dataframe.drop(dataframe[(dataframe['location.postalCode'] == 'NaN')].index(), inplace=True)

# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in coffee_shop.columns if col.startswith('location.')] + ['id']
coffee_shop = coffee_shop.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
coffee_shop['categories'] = coffee_shop.apply(get_category_type, axis=1)

# clean column names by keeping only last term
coffee_shop.columns = [column.split('.')[-1] for column in coffee_shop.columns]

#Keep only first 3 of Postcode
coffee_shop['Postcode'] = coffee_shop['postalCode'].str[:3]

coffee_shop.head()
# Out:
#                                        name   categories              address  \
# 0       Super Jet International Coffee Shop  Coffee Shop      267 College St.
# 1  Bluestone Lane Queen Station Coffee Shop         Café  2 Queen Street East
# 2                       Niagara coffee shop  Coffee Shop          Niagara St.
# 3                GRIP 6th Floor Coffee Shop  Coffee Shop         179 John St.
# 4                          Luis Coffee Shop  Coffee Shop       235 Augusta St
#
#    cc     city country        crossStreet  distance  \
# 0  CA  Toronto  Canada        Spadina Ave      1371
# 1  CA  Toronto  Canada                NaN       406
# 2  CA  Toronto  Canada                NaN      1973
# 3  CA  Toronto  Canada       at Queen St.       649
# 4  CA  Toronto  Canada  Baldwin & Augusta      1460
#
#                                     formattedAddress  \
# 0  [267 College St. (Spadina Ave), Toronto ON M5T...
# 1  [2 Queen Street East, Toronto ON M5C 3G5, Canada]
# 2                  [Niagara St., Toronto ON, Canada]
# 3  [179 John St. (at Queen St.), Toronto ON M5T 1...
# 4  [235 Augusta St (Baldwin & Augusta), Toronto O...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.657971, 'lng':...  43.657971 -79.399795
# 1  [{'label': 'display', 'lat': 43.6525684, 'lng'...  43.652568 -79.379047
# 2  [{'label': 'display', 'lat': 43.64188299139057...  43.641883 -79.402463
# 3  [{'label': 'display', 'lat': 43.65103493678703...  43.651035 -79.391256
# 4  [{'label': 'display', 'lat': 43.654575, 'lng':...  43.654575 -79.402006
#
#   neighborhood postalCode state                        id Postcode
# 0          NaN    M5T 1R5    ON  5ae32b6412c8f0002c2b03e7      M5T
# 1          NaN    M5C 3G5    ON  5d493dc5735c2d0007bc3966      M5C
# 2          NaN        NaN    ON  4bc796086501c9b6a1ba3e29      NaN
# 3          NaN    M5T 1X4    ON  4c6bd9de69b4ef3b4d51474e      M5T
# 4          NaN    M5T 1M1    ON  4ae92277f964a52072b421e3      M5T

# %%
coffee_shop.groupby('categories').count()
# Out:
#                      name  address  cc  city  country  crossStreet  distance  \
# categories
# Bakery                  1        1   1     1        1            1         1
# Business Service        1        1   1     1        1            0         1
# Café                    8        3   8     6        8            2         8
# Coffee Shop            30       25  30    26       30           19        30
# College Cafeteria       1        1   1     1        1            0         1
# Pop-Up Shop             1        1   1     1        1            1         1
# Pub                     1        1   1     1        1            1         1
# Restaurant              3        3   3     3        3            0         3
# Sporting Goods Shop     1        1   1     1        1            1         1
# Sushi Restaurant        1        1   1     1        1            0         1
#
#                      formattedAddress  labeledLatLngs  lat  lng  neighborhood  \
# categories
# Bakery                              1               1    1    1             0
# Business Service                    1               1    1    1             0
# Café                                8               8    8    8             0
# Coffee Shop                        30              30   30   30             2
# College Cafeteria                   1               1    1    1             0
# Pop-Up Shop                         1               1    1    1             0
# Pub                                 1               1    1    1             0
# Restaurant                          3               3    3    3             0
# Sporting Goods Shop                 1               1    1    1             0
# Sushi Restaurant                    1               1    1    1             0
#
#                      postalCode  state  id  Postcode
# categories
# Bakery                        1      1   1         1
# Business Service              1      1   1         1
# Café                          2      6   8         2
# Coffee Shop                  16     26  30        16
# College Cafeteria             1      1   1         1
# Pop-Up Shop                   1      1   1         1
# Pub                           0      1   1         0
# Restaurant                    3      3   3         3
# Sporting Goods Shop           1      1   1         1
# Sushi Restaurant              1      1   1         1

# %%
#keep only category Coffee Shop
coffee_shop = coffee_shop.loc[(coffee_shop['categories'] == 'Coffee Shop')].reset_index()
coffee_shop.head()
# Out:
#    index                                 name   categories          address  \
# 0      0  Super Jet International Coffee Shop  Coffee Shop  267 College St.
# 1      2                  Niagara coffee shop  Coffee Shop      Niagara St.
# 2      3           GRIP 6th Floor Coffee Shop  Coffee Shop     179 John St.
# 3      4                     Luis Coffee Shop  Coffee Shop   235 Augusta St
# 4      5      John Ford's Classic Coffee Shop  Coffee Shop       1 Yonge St
#
#    cc     city country            crossStreet  distance  \
# 0  CA  Toronto  Canada            Spadina Ave      1371
# 1  CA  Toronto  Canada                    NaN      1973
# 2  CA  Toronto  Canada           at Queen St.       649
# 3  CA  Toronto  Canada      Baldwin & Augusta      1460
# 4  CA  Toronto  Canada  Yonge and Queens Quay      1491
#
#                                     formattedAddress  \
# 0  [267 College St. (Spadina Ave), Toronto ON M5T...
# 1                  [Niagara St., Toronto ON, Canada]
# 2  [179 John St. (at Queen St.), Toronto ON M5T 1...
# 3  [235 Augusta St (Baldwin & Augusta), Toronto O...
# 4  [1 Yonge St (Yonge and Queens Quay), Toronto O...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.657971, 'lng':...  43.657971 -79.399795
# 1  [{'label': 'display', 'lat': 43.64188299139057...  43.641883 -79.402463
# 2  [{'label': 'display', 'lat': 43.65103493678703...  43.651035 -79.391256
# 3  [{'label': 'display', 'lat': 43.654575, 'lng':...  43.654575 -79.402006
# 4  [{'label': 'display', 'lat': 43.64191404782495...  43.641914 -79.374590
#
#   neighborhood postalCode state                        id Postcode
# 0          NaN    M5T 1R5    ON  5ae32b6412c8f0002c2b03e7      M5T
# 1          NaN        NaN    ON  4bc796086501c9b6a1ba3e29      NaN
# 2          NaN    M5T 1X4    ON  4c6bd9de69b4ef3b4d51474e      M5T
# 3          NaN    M5T 1M1    ON  4ae92277f964a52072b421e3      M5T
# 4          NaN    M5J 2S7    ON  4fe359f6d5fb75c734446273      M5J

# %%
italian_restaurant_map = folium.Map(location=[latitude, longitude], zoom_start=15)

# instantiate a mark cluster object for the incidents in the dataframe
#italian_restaurant_df_marker = plugins.MarkerCluster().add_to(italian_restaurant_map)

# add markers to map
for lat, lng, label in zip(italian_restaurant_df['lat'], italian_restaurant_df['lng'], italian_restaurant_df['name']):
    label = '{}'.format(label)
    label = folium.Popup(label, parse_html=True)
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(italian_restaurant_map)

# add markers of Coffee Shops to map
for lat, lng, label in zip(coffee_shop['lat'], coffee_shop['lng'], coffee_shop['name']):
    label = '{}'.format(label)
    label = folium.Popup(label, parse_html=True)
    folium.Marker(
        location=[lat, lng],
        icon=folium.Icon(color = 'green'),
        popup=label,
    ).add_to(italian_restaurant_map)
    
italian_restaurant_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# From the above map we can see that a good area where there are Coffee Shops and not too many Italian Restaurants is the rectangle between "Osgoode", "St. Patrick", "Dundas" and "Queen".
#
# Let's try to refine our search by looking at other venues

# %%
#Second search: Bar
search_query = 'Bar'
radius = 50000

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

bar = requests.get(url).json()
# assign relevant part of JSON to venues
venues_bar = bar['response']['venues']
# tranform venues into a dataframe
bar = json_normalize(venues_bar)
#dataframe.drop(dataframe[(dataframe['location.postalCode'] == 'NaN')].index(), inplace=True)

# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in bar.columns if col.startswith('location.')] + ['id']
bar = bar.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
bar['categories'] = bar.apply(get_category_type, axis=1)

# clean column names by keeping only last term
bar.columns = [column.split('.')[-1] for column in bar.columns]

#Keep only first 3 of Postcode
bar['Postcode'] = bar['postalCode'].str[:3]

bar.head()
# Out:
#                        name               categories  \
# 0     St. Louis Bar & Grill                      Bar
# 1    Blue Stone Grill & Bar                      Pub
# 2                 Bar Verde  New American Restaurant
# 3  Quinn's Steakhouse & Bar               Steakhouse
# 4            Barristers Bar               Restaurant
#
#                     address  cc     city country      crossStreet  distance  \
# 0           595 Bay St #A09  CA  Toronto  Canada    Atrium on Bay       356
# 1               372 Bay St.  CA  Toronto  Canada  at Richmond St.       340
# 2          260 Yonge Street  CA  Toronto  Canada              NaN       298
# 3   96 Richmond Street West  CA  Toronto  Canada           at Bay       265
# 4  145 Richmond Street West  CA  Toronto  Canada   Hilton Toronto       437
#
#                                     formattedAddress  \
# 0  [595 Bay St #A09 (Atrium on Bay), Toronto ON M...
# 1  [372 Bay St. (at Richmond St.), Toronto ON M5H...
# 2     [260 Yonge Street, Toronto ON M5B 2L9, Canada]
# 3  [96 Richmond Street West (at Bay), Toronto ON ...
# 4  [145 Richmond Street West (Hilton Toronto), To...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65656209045694...  43.656562 -79.382737
# 1  [{'label': 'display', 'lat': 43.65118713330148...  43.651187 -79.381139
# 2  [{'label': 'display', 'lat': 43.654837, 'lng':...  43.654837 -79.380742
# 3  [{'label': 'display', 'lat': 43.65119745750837...  43.651197 -79.382976
# 4  [{'label': 'display', 'lat': 43.64979669604817...  43.649797 -79.385807
#
#          neighborhood postalCode state                        id Postcode
# 0                 NaN    M5G 2C2    ON  4af4e6e2f964a52052f721e3      M5G
# 1                 NaN    M5H 1M7    ON  4af8da92f964a5204a1022e3      M5H
# 2                 NaN    M5B 2L9    ON  57dd99cb498ee67580d16390      M5B
# 3  Financial District    M5H 2A3    ON  4b3db5e4f964a520709625e3      M5H
# 4                 NaN    M5H 2L2    ON  50ca02be245f2d4aa8c2ab5b      M5H

# %%
bar.groupby('categories').count()
# Out:
#                          name  address  cc  city  country  crossStreet  \
# categories
# American Restaurant         2        2   2     2        2            2
# BBQ Joint                   1        1   1     1        1            1
# Bar                         5        5   5     5        5            3
# Beer Bar                    1        1   1     1        1            1
# Café                        4        4   4     4        4            4
# Cocktail Bar                1        1   1     1        1            1
# Coffee Shop                 3        3   3     3        3            1
# Diner                       1        1   1     1        1            1
# Health & Beauty Service     1        0   1     1        1            0
# Hotel Bar                   5        5   5     5        5            3
# Italian Restaurant          2        2   2     2        2            1
# Japanese Restaurant         1        1   1     1        1            1
# Jazz Club                   1        1   1     1        1            1
# Karaoke Bar                 2        2   2     2        2            1
# New American Restaurant     1        1   1     1        1            0
# Nightclub                   1        1   1     1        1            1
# Pub                         1        1   1     1        1            1
# Restaurant                  4        4   4     4        4            2
# Salon / Barbershop          2        2   2     2        2            1
# Soup Place                  1        1   1     1        1            0
# Spanish Restaurant          1        1   1     1        1            0
# Speakeasy                   2        0   2     0        2            0
# Sports Bar                  1        1   1     1        1            1
# Steakhouse                  4        4   4     4        4            2
# Venezuelan Restaurant       1        1   1     1        1            0
# Wings Joint                 1        1   1     1        1            1
#
#                          distance  formattedAddress  labeledLatLngs  lat  lng  \
# categories
# American Restaurant             2                 2               2    2    2
# BBQ Joint                       1                 1               1    1    1
# Bar                             5                 5               5    5    5
# Beer Bar                        1                 1               1    1    1
# Café                            4                 4               4    4    4
# Cocktail Bar                    1                 1               1    1    1
# Coffee Shop                     3                 3               3    3    3
# Diner                           1                 1               1    1    1
# Health & Beauty Service         1                 1               1    1    1
# Hotel Bar                       5                 5               5    5    5
# Italian Restaurant              2                 2               2    2    2
# Japanese Restaurant             1                 1               1    1    1
# Jazz Club                       1                 1               1    1    1
# Karaoke Bar                     2                 2               2    2    2
# New American Restaurant         1                 1               1    1    1
# Nightclub                       1                 1               1    1    1
# Pub                             1                 1               1    1    1
# Restaurant                      4                 4               4    4    4
# Salon / Barbershop              2                 2               2    2    2
# Soup Place                      1                 1               1    1    1
# Spanish Restaurant              1                 1               1    1    1
# Speakeasy                       2                 2               2    2    2
# Sports Bar                      1                 1               1    1    1
# Steakhouse                      4                 4               4    4    4
# Venezuelan Restaurant           1                 1               1    1    1
# Wings Joint                     1                 1               1    1    1
#
#                          neighborhood  postalCode  state  id  Postcode
# categories
# American Restaurant                 0           2      2   2         2
# BBQ Joint                           0           1      1   1         1
# Bar                                 0           4      5   5         4
# Beer Bar                            0           1      1   1         1
# Café                                0           1      4   4         1
# Cocktail Bar                        0           1      1   1         1
# Coffee Shop                         0           2      3   3         2
# Diner                               0           0      1   1         0
# Health & Beauty Service             0           1      1   1         1
# Hotel Bar                           0           4      5   5         4
# Italian Restaurant                  0           2      2   2         2
# Japanese Restaurant                 0           1      1   1         1
# Jazz Club                           0           1      1   1         1
# Karaoke Bar                         0           1      2   2         1
# New American Restaurant             0           1      1   1         1
# Nightclub                           0           0      1   1         0
# Pub                                 0           1      1   1         1
# Restaurant                          0           4      4   4         4
# Salon / Barbershop                  0           1      2   2         1
# Soup Place                          0           1      1   1         1
# Spanish Restaurant                  0           1      1   1         1
# Speakeasy                           0           0      0   2         0
# Sports Bar                          0           1      1   1         1
# Steakhouse                          1           3      4   4         3
# Venezuelan Restaurant               0           1      1   1         1
# Wings Joint                         0           1      1   1         1

# %%
italian_restaurant_map = folium.Map(location=[latitude, longitude], zoom_start=14)

# instantiate a mark cluster object for the incidents in the dataframe
#italian_restaurant_df_marker = plugins.MarkerCluster().add_to(italian_restaurant_map)

# add markers to map
for lat, lng, label in zip(italian_restaurant_df['lat'], italian_restaurant_df['lng'], italian_restaurant_df['name']):
    label = '{}'.format(label)
    label = folium.Popup(label, parse_html=True)
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(italian_restaurant_map)
    
# add markers of Bars to map
for lat, lng, label in zip(bar['lat'], bar['lng'], bar['name']):
    label = '{}'.format(label)
    label = folium.Popup(label, parse_html=True)
    folium.Marker(
        location=[lat, lng],
        icon=folium.Icon(color = 'red'),
        popup=label,
    ).add_to(italian_restaurant_map)
    
italian_restaurant_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# This result seems to give us other inputs; the location of venues that are typically found near Italian Restaurant opens the area expanding it up to Toronto Union Station.
#
# Let's try the third popular venue

# %%
#Third search: hotel
search_query = 'Hotel'
radius = 50000

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

hotel = requests.get(url).json()
# assign relevant part of JSON to venues
venues_hotel = hotel['response']['venues']
# tranform venues into a dataframe
hotel = json_normalize(venues_hotel)
#dataframe.drop(dataframe[(dataframe['location.postalCode'] == 'NaN')].index(), inplace=True)

# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in hotel.columns if col.startswith('location.')] + ['id']
hotel = hotel.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
hotel['categories'] = hotel.apply(get_category_type, axis=1)

# clean column names by keeping only last term
hotel.columns = [column.split('.')[-1] for column in hotel.columns]

#Keep only first 3 of Postcode
hotel['Postcode'] = hotel['postalCode'].str[:3]

hotel.head()
# Out:
#                               name categories                 address  cc  \
# 0    Sheraton Centre Toronto Hotel      Hotel   123 Queen Street West  CA
# 1                    Chelsea Hotel      Hotel  33 Gerrard Street West  CA
# 2  One King West Hotel & Residence      Hotel             1 King St W  CA
# 3                 Bond Place Hotel      Hotel          65 Dundas St E  CA
# 4             Pantages Hotel & Spa      Hotel         200 Victoria St  CA
#
#       city country   crossStreet  distance  \
# 0  Toronto  Canada   at York St.       324
# 1  Toronto  Canada   at Yonge St       562
# 2  Toronto  Canada  at Yonge St.       686
# 3  Toronto  Canada   at Bond St.       534
# 4  Toronto  Canada  at Shuter St       410
#
#                                     formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [33 Gerrard Street West (at Yonge St), Toronto...
# 2  [1 King St W (at Yonge St.), Toronto ON M5H 1A...
# 3  [65 Dundas St E (at Bond St.), Toronto ON M5B ...
# 4  [200 Victoria St (at Shuter St), Toronto ON, C...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.6505944, 'lng'...  43.650594 -79.384530
# 1  [{'label': 'display', 'lat': 43.65849759157591...  43.658498 -79.383097
# 2  [{'label': 'display', 'lat': 43.6491395, 'lng'...  43.649139 -79.377876
# 3  [{'label': 'display', 'lat': 43.65618805882607...  43.656188 -79.378452
# 4  [{'label': 'display', 'lat': 43.65449797039222...  43.654498 -79.379035
#
#   neighborhood postalCode state                        id Postcode
# 0          NaN    M5H 2M9    ON  4ab2d511f964a5209b6c20e3      M5H
# 1          NaN    M5G 1Z4    ON  51d212c3498ebf27dc469bc9      M5G
# 2          NaN    M5H 1A1    ON  4af96fbbf964a520c01122e3      M5H
# 3          NaN    M5B 2G8    ON  4ad4c05bf964a520a3f520e3      M5B
# 4          NaN        NaN    ON  4ae61cf6f964a520caa421e3      NaN

# %%
hotel.groupby('categories').count()
# Out:
#                                           name  address  cc  city  country  \
# categories
# Ballroom                                     1        1   1     1        1
# College Residence Hall                       1        1   1     1        1
# Convention Center                            1        1   1     1        1
# Gym                                          1        1   1     1        1
# Gym / Fitness Center                         1        0   1     0        1
# Hotel                                       36       32  36    34       36
# Jazz Club                                    1        1   1     1        1
# Lounge                                       1        0   1     1        1
# Miscellaneous Shop                           1        1   1     0        1
# Pool                                         1        1   1     1        1
# Residential Building (Apartment / Condo)     3        2   3     3        3
# Spa                                          2        2   2     2        2
#
#                                           crossStreet  distance  \
# categories
# Ballroom                                            1         1
# College Residence Hall                              0         1
# Convention Center                                   0         1
# Gym                                                 0         1
# Gym / Fitness Center                                0         1
# Hotel                                              21        36
# Jazz Club                                           1         1
# Lounge                                              0         1
# Miscellaneous Shop                                  0         1
# Pool                                                0         1
# Residential Building (Apartment / Condo)            0         3
# Spa                                                 1         2
#
#                                           formattedAddress  labeledLatLngs  \
# categories
# Ballroom                                                 1               1
# College Residence Hall                                   1               1
# Convention Center                                        1               1
# Gym                                                      1               1
# Gym / Fitness Center                                     1               1
# Hotel                                                   36              36
# Jazz Club                                                1               1
# Lounge                                                   1               1
# Miscellaneous Shop                                       1               1
# Pool                                                     1               1
# Residential Building (Apartment / Condo)                 3               3
# Spa                                                      2               2
#
#                                           lat  lng  neighborhood  postalCode  \
# categories
# Ballroom                                    1    1             1           0
# College Residence Hall                      1    1             0           1
# Convention Center                           1    1             0           1
# Gym                                         1    1             0           1
# Gym / Fitness Center                        1    1             1           0
# Hotel                                      36   36             1          26
# Jazz Club                                   1    1             0           1
# Lounge                                      1    1             0           1
# Miscellaneous Shop                          1    1             0           0
# Pool                                        1    1             0           0
# Residential Building (Apartment / Condo)    3    3             0           1
# Spa                                         2    2             0           1
#
#                                           state  id  Postcode
# categories
# Ballroom                                      1   1         0
# College Residence Hall                        1   1         1
# Convention Center                             1   1         1
# Gym                                           1   1         1
# Gym / Fitness Center                          0   1         0
# Hotel                                        34  36        26
# Jazz Club                                     1   1         1
# Lounge                                        1   1         1
# Miscellaneous Shop                            0   1         0
# Pool                                          1   1         0
# Residential Building (Apartment / Condo)      3   3         1
# Spa                                           2   2         1

# %%
italian_restaurant_map = folium.Map(location=[latitude, longitude], zoom_start=15)

# instantiate a mark cluster object for the incidents in the dataframe
#italian_restaurant_df_marker = plugins.MarkerCluster().add_to(italian_restaurant_map)

# add markers to map
for lat, lng, label in zip(italian_restaurant_df['lat'], italian_restaurant_df['lng'], italian_restaurant_df['name']):
    label = '{}'.format(label)
    label = folium.Popup(label, parse_html=True)
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(italian_restaurant_map)
    
# add markers of Hotels to map
for lat, lng, label in zip(hotel['lat'], hotel['lng'], hotel['name']):
    label = '{}'.format(label)
    label = folium.Popup(label, parse_html=True)
    folium.Marker(
        location=[lat, lng],
        icon=folium.Icon(color = 'orange'),
        popup=label,
    ).add_to(italian_restaurant_map)
    
italian_restaurant_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# This last search confirms what we found above; the area in which the most popular venues commonly found near Italian Restaurants is from Queen's Park up to Toronto Union Station.
#
# Let's put everything together.

# %%
italian_restaurant_map = folium.Map(location=[latitude, longitude], zoom_start=15)

# instantiate a mark cluster object for the incidents in the dataframe
#italian_restaurant_df_marker = plugins.MarkerCluster().add_to(italian_restaurant_map)

# add markers to map
for lat, lng, label in zip(italian_restaurant_df['lat'], italian_restaurant_df['lng'], italian_restaurant_df['name']):
    label = '{}'.format(label)
    label = folium.Popup(label, parse_html=True)
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(italian_restaurant_map)
    
# add markers of Hotels to map
for lat, lng, label in zip(hotel['lat'], hotel['lng'], hotel['name']):
    label = '{}'.format(label)
    label = folium.Popup(label, parse_html=True)
    folium.Marker(
        location=[lat, lng],
        icon=folium.Icon(color = 'orange'),
        popup=label,
    ).add_to(italian_restaurant_map)
    
# add markers of Bars to map
for lat, lng, label in zip(bar['lat'], bar['lng'], bar['name']):
    label = '{}'.format(label)
    label = folium.Popup(label, parse_html=True)
    folium.Marker(
        location=[lat, lng],
        icon=folium.Icon(color = 'red'),
        popup=label,
    ).add_to(italian_restaurant_map)
    

# add markers of Coffee Shops to map
for lat, lng, label in zip(coffee_shop['lat'], coffee_shop['lng'], coffee_shop['name']):
    label = '{}'.format(label)
    label = folium.Popup(label, parse_html=True)
    folium.Marker(
        location=[lat, lng],
        icon=folium.Icon(color = 'green'),
        popup=label,
    ).add_to(italian_restaurant_map)
    
    
italian_restaurant_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# This picture shows Italian Restaurants and other venues we analysed in a single map zoomed to show the area of interest. As we can see, we can now refine the area suggested for an Italian Restaurant to Adelaide Street West or Adelaide Street East.

# %% [markdown]
# ## Results and Discussion <a name="conclusion"></a>

# %% [markdown]
# From above results we can now conclude that
#
# 1. Many popular venues are located in a rectangle defined by Richmond Street West, Church Street, Front Street and Queen Street.
# 2. In this area there are 3 other Italian Restaurants near University Avenue
# 3. University Avenue splits the area of interest in 2 sub-areas (East and West)
# 4. Our suggestion for the location of a new Italian Restaurant is then near Adelaide Street West or Adelaide Street East in order to have the Restaurant located near interesting venues but not too close to other Italian Restaurants that are already well established in the city.
#
# This analysis gave us only a suggestion of a possible location of an Italian Restaurant. The variables we considered were only a few of all the possible ones we may have analysed, such as position of parkings, presence of restaurants serving other cuisine type and cost of the rent. Further analysis including these variables may help us in refining our search more and finding a more suitable location to suggest to our customer.
